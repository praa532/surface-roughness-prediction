# %%
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
# from sklearn.ensemble import StackingRegressor
# from sklearn.ensemble import VotingRegressor
# from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

import pandas
from sklearn import model_selection
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split



model1 = MLPRegressor()
model2 = ExtraTreesRegressor()
model3 = AdaBoostRegressor()
model4 = BaggingRegressor()
model5 = GradientBoostingRegressor()
model6 = RandomForestRegressor()
model7 = KNeighborsRegressor()
model8 = MLPRegressor()
model9 = XGBRegressor()
model10 = SGDRegressor()
model11 = LinearRegression()
model12 = LinearSVR()
model13 = SVR()
model14 = DecisionTreeRegressor()
# model7 = StackingRegressor()
# model8 = VotingRegressor()
# model9 = HistGradientBoostingRegressor()




dataset = pd.read_csv("Machining Data.csv")
data = dataset.values
X, y = data[:, :-1], data[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=981)

print("model 1")
model1.fit(X_train,y_train)
preds = model1.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model1_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model1_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 2")
model2.fit(X_train,y_train)
preds = model2.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model2_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model2_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 3")
model3.fit(X_train,y_train)
preds = model3.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model3_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model3_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 4")
model4.fit(X_train,y_train)
preds = model4.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model4_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model4_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 5")
model2.fit(X_train,y_train)
preds = model2.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model5_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model5_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 6")
model6.fit(X_train,y_train)
preds = model6.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model6_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model6_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 7")
model7.fit(X_train,y_train)
preds = model7.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model7_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model7_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")


print("model 8")
model8.fit(X_train,y_train)
preds = model8.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model8_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model8_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")




print("model 9")
model9.fit(X_train,y_train)
preds = model9.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model9_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model9_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



print("model 10")
model10.fit(X_train,y_train)
preds = model10.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model10_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model10_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



print("model 11")
model11.fit(X_train,y_train)
preds = model11.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model11_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model11_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



print("model 12")
model12.fit(X_train,y_train)
preds = model12.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model12_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model12_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



print("model 13")
model13.fit(X_train,y_train)
preds = model13.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model13_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model13_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



print("model 14")
model14.fit(X_train,y_train)
preds = model14.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
mse = (mean_squared_error(y_test, preds))
print("MSE: %f" % (mse))
np.savetxt("model14_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
np.savetxt("model14_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")




# model15.fit(X_train,y_train)
# preds = model15.predict(X_test)
# rmse = np.sqrt(mean_squared_error(y_test, preds))
# print("RMSE: %f" % (rmse))
# mse = (mean_squared_error(y_test, preds))
# print("MSE: %f" % (mse))
# np.savetxt("model15_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
# np.savetxt("model15_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")



# print("model 16")
# model16.fit(X_train,y_train)
# preds = model16.predict(X_test)
# rmse = np.sqrt(mean_squared_error(y_test, preds))
# print("RMSE: %f" % (rmse))
# mse = (mean_squared_error(y_test, preds))
# print("MSE: %f" % (mse))
# np.savetxt("model16_353_1M_beha_predictions_sheet1_score1.csv", preds, delimiter=",")
# np.savetxt("model16_353_1M_beha_groundtruth_sheet1_score1.csv", y_test, delimiter=",")
